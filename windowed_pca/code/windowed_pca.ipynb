# %%
#!/usr/bin/env python
#
# Moritz Blumer | 2021-12-07 (2023-03-15)
#
# Conduct sliding window PCA with scikit-allel 


#### GET RID OF ORDER BY GT FILE, OR NOT? --> TEST IF CURRENT VERSION CAUSES PROBLEMS

#### FIX PCT INCLUDED SITES SCALE + ABRUNDEN PC % EXP VALUES

#### add check whether input samples are unique (if not len(set(input_salmpes)) == ...)

#### add [INFO]



# The minimum number of variants per window is set to 50 and can be changed below (NA will be returned for windows with fewer variants)
min_var_per_window = 50
var_threshold = 9
mean_threshold = 3
float_precision = 7

# import packages
import allel
import sys, os
import numpy as np
import pandas as pd

# %%
# set arguments
variant_file_path = '../test_dataset/input/genotype_file.tsv.gz'
#variant_file_path = '../test_dataset/input/sample.vcf'
metadata_path = '../test_dataset/input/metadata.tsv'

chrom = 'chr1'
pc=1
skip_monomorphic = True
output_prefix = 'test_out'
output_prefix = output_prefix.lower()
color_taxon = 'inversion_state'
w_size = 1000000
w_step = 10000
region = '1-34999238'
start = int(region.split('-')[0])
stop = int(region.split('-')[1])

# %%
## private functions

# main PCA function, using scikit-allel
def pca(win, w_start, w_size):
    '''
    Conduct PCA, but if (n_variants < min_var_per_window) generate empty/dummy output instead
    '''

    # trim off pos info
    win = [x[1:] for x in win]

    # get window mid for X value
    w_mid = int(w_start + w_size/2-1)

    # count variants
    n_variants = len(win)

    # if # variants passes specified threshold  
    if n_variants > min_var_per_window: # CHANGE TO: "if n_variants >= min_var_per_window:" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        w_gt_arr = np.array(win, dtype=np.int8)
        pca = allel.pca(w_gt_arr, n_components=2, copy=True, scaler='patterson', ploidy=2)
        out = [pca[0][: , 0], pca[0][: , 1], pca[1].explained_variance_ratio_[0]*100, pca[1].explained_variance_ratio_[1]*100, n_variants]

    # else create empty output
    else:
        print('[INFO] Skipped window ' + str(w_start) + '-' + str(w_start + w_size-1) + ' with ' + str(n_variants) + ' variants (threshold is ' + str(min_var_per_window) + ' variants per window)', file=sys.stderr, flush=True)
        empty_array = [None] * len(win[0])
        out = [empty_array, empty_array, None, None, n_variants]

    # append output
    w_mid_lst.append(w_mid)
    w_pca_lst.append(out[0]) if pc==1 else out[1] # depending on whether PC1 or PC2 was specified, append out[0] or out[1], respectively
    w_stats_lst.append([out[2], out[3], out[4]])


# frame for window-by-window analysis
def windowed_pca(variant_file_path, chrom, start, stop, metadata_df, pca, w_size, w_step, skip_monomorphic=True):

    global w_mid_lst, w_pca_lst, w_stats_lst

    # # initialize results containers
    w_mid_lst = []
    w_pca_lst = []
    w_stats_lst = []

    # # conduct windowed PCA using window_parser() function
    if variant_file_path.endswith('.vcf') or variant_file_path.endswith('.vcf.gz'):
        from window_parser import win_vcf
        win_vcf(variant_file_path, chrom, start, stop, metadata_df['id'], w_size, w_step, pca, skip_monomorphic=skip_monomorphic)

    elif variant_file_path.endswith('.tsv') or variant_file_path.endswith('.tsv.gz'):
        from window_parser import win_gt_file
        win_gt_file(variant_file_path, chrom, start, stop, metadata_df['id'], w_size, w_step, pca, skip_monomorphic=skip_monomorphic)

    # compile output dataframe for windowed PCA
    w_pca_df = pd.DataFrame(np.transpose(w_pca_lst), index=list(metadata_df['id']), columns=w_mid_lst)
    w_pca_df.index.names = ['id']

    # compile output dataframe for supplementary info (% variance explained, # sites per window)
    w_stats_df = pd.DataFrame(w_stats_lst, index=w_mid_lst, columns=['pct_explained_pc_1', 'pct_explained_pc_2', 'num_variants'])
    w_stats_df.index.names = ['window_mid']
    w_stats_df['pct_included_sites'] = w_stats_df['num_variants']/w_size/100

    return w_pca_df, w_stats_df

# %%
def main():

    #parse_arguments()

    # compile paths for the six output files
    w_pca_tsv_path =        output_prefix + '.w_pc_' + str(pc) + '.tsv.gz'
    w_stats_tsv_path =      output_prefix + '.w_stats'          + '.tsv.gz'
    w_pca_fig_html_path =   output_prefix + '.w_pc_' + str(pc) + '.html'
    w_pca_fig_pdf_path =    output_prefix + '.w_pc_' + str(pc) + '.pdf'
    w_stats_fig_html_path = output_prefix + '.w_stats'         + '.html'
    w_stats_fig_pdf_path =  output_prefix + '.w_stats'         + '.pdf'

    # set float format for text output
    pd.set_option('display.float_format', lambda x: '%.3f' % x)

    # read metadata
    from utils import read_metadata
    metadata_df = read_metadata(variant_file_path, metadata_path, taxon='species', group='species_1,species_2')

    # if there is output from a previous run read it in
    if os.path.exists(w_pca_tsv_path) and os.path.exists(w_stats_tsv_path):

        w_pca_df = pd.read_csv(w_pca_tsv_path,  sep='\t', index_col=None, na_values='NA')
        w_stats_df = pd.read_csv(w_stats_tsv_path,  sep='\t', index_col=None, na_values='NA')

    else:
        # run windowed PCA
        w_pca_df, w_stats_df = windowed_pca(variant_file_path, chrom, start, stop, metadata_df, pca, w_size, w_step, skip_monomorphic)

        # polarize windowed PCA output
        from utils import polarize
        w_pca_df = polarize(w_pca_df, var_threshold=9, mean_threshold=3, guide_samples=False) ##### ADJUST THIS

        # save output data before annotation if not already present
        w_pca_df.to_csv(w_pca_tsv_path, sep='\t', na_rep='NA', float_format='%.' + str(float_precision) + 'f', compression='gzip')
        w_stats_df.to_csv(w_stats_tsv_path, sep='\t', na_rep='NA', float_format='%.' + str(float_precision) + 'f', compression='gzip')

    # pivot windowed pca output and annotate with metadata
    from utils import annotate
    w_pca_anno_df = annotate(w_pca_df, metadata_df, 'pc_' + str(pc))

    # free up memory
    del w_pca_df

    # plot windowed PCA output & save
    from utils import plot_w_pca
    w_pca_fig = plot_w_pca(w_pca_anno_df, 1, color_taxon, chrom, start, stop, w_size, w_step)
    w_pca_fig.write_html(w_pca_fig_html_path)
    w_pca_fig.write_image(w_pca_fig_pdf_path, engine='kaleido', scale=2.4)

    # free up memory
    del w_pca_fig

    # plot window stats & save
    from utils import plot_w_stats
    w_stats_fig = plot_w_stats(w_stats_df, chrom, start, stop, w_size, w_step)
    w_stats_fig.write_html(w_stats_fig_html_path)
    w_stats_fig.write_image(w_stats_fig_pdf_path, engine='kaleido', scale=2.4)

if __name__ == "__main__":
    main()
# Out:
# [INFO] Processed 228 of 3400 windows
# [INFO] Processed 229 of 3400 windows
# [INFO] Processed 230 of 3400 windows
# [INFO] Processed 231 of 3400 windows
# [INFO] Processed 232 of 3400 windows
# [INFO] Processed 233 of 3400 windows
# [INFO] Processed 234 of 3400 windows
# [INFO] Processed 235 of 3400 windows
# [INFO] Processed 236 of 3400 windows
# [INFO] Processed 237 of 3400 windows
# [INFO] Processed 238 of 3400 windows
# [INFO] Processed 239 of 3400 windows
# [INFO] Processed 240 of 3400 windows
# [INFO] Processed 241 of 3400 windows
# [INFO] Processed 242 of 3400 windows
# [INFO] Processed 243 of 3400 windows
# [INFO] Processed 244 of 3400 windows
# [INFO] Processed 245 of 3400 windows
# [INFO] Processed 246 of 3400 windows
# [INFO] Processed 247 of 3400 windows
# [INFO] Processed 248 of 3400 windows
# [INFO] Processed 249 of 3400 windows
# [INFO] Processed 250 of 3400 windows
# [INFO] Processed 251 of 3400 windows
# [INFO] Processed 252 of 3400 windows
# [INFO] Processed 253 of 3400 windows
# [INFO] Processed 254 of 3400 windows
# [INFO] Processed 255 of 3400 windows
# [INFO] Processed 256 of 3400 windows
# [INFO] Processed 257 of 3400 windows
# [INFO] Processed 258 of 3400 windows
# [INFO] Processed 259 of 3400 windows
# [INFO] Processed 260 of 3400 windows
# [INFO] Processed 261 of 3400 windows
# [INFO] Processed 262 of 3400 windows
# [INFO] Processed 263 of 3400 windows
# [INFO] Processed 264 of 3400 windows
# [INFO] Processed 265 of 3400 windows
# [INFO] Processed 266 of 3400 windows
# [INFO] Processed 267 of 3400 windows
# [INFO] Processed 268 of 3400 windows
# [INFO] Processed 269 of 3400 windows
# [INFO] Processed 270 of 3400 windows
# [INFO] Processed 271 of 3400 windows
# [INFO] Processed 272 of 3400 windows
# [INFO] Processed 273 of 3400 windows
# [INFO] Processed 274 of 3400 windows
# [INFO] Processed 275 of 3400 windows
# [INFO] Processed 276 of 3400 windows
# [INFO] Processed 277 of 3400 windows
# [INFO] Processed 278 of 3400 windows
# [INFO] Processed 279 of 3400 windows
# [INFO] Processed 280 of 3400 windows
# [INFO] Processed 281 of 3400 windows
# [INFO] Processed 282 of 3400 windows
# [INFO] Processed 283 of 3400 windows
# [INFO] Processed 284 of 3400 windows
# [INFO] Processed 285 of 3400 windows
# [INFO] Processed 286 of 3400 windows
# [INFO] Processed 287 of 3400 windows
# [INFO] Skipped window 2870001-3870000 with 49 variants (threshold is 50 variants per window)
# [INFO] Processed 288 of 3400 windows
# [INFO] Skipped window 2880001-3880000 with 49 variants (threshold is 50 variants per window)
# [INFO] Processed 289 of 3400 windows
# [INFO] Skipped window 2890001-3890000 with 49 variants (threshold is 50 variants per window)
# [INFO] Processed 290 of 3400 windows
# [INFO] Skipped window 2900001-3900000 with 47 variants (threshold is 50 variants per window)
# [INFO] Processed 291 of 3400 windows
# [INFO] Skipped window 2910001-3910000 with 46 variants (threshold is 50 variants per window)
# [INFO] Processed 292 of 3400 windows
# [INFO] Processed 293 of 3400 windows
# [INFO] Processed 294 of 3400 windows
# [INFO] Skipped window 2940001-3940000 with 50 variants (threshold is 50 variants per window)
# [INFO] Processed 295 of 3400 windows
# [INFO] Skipped window 2950001-3950000 with 50 variants (threshold is 50 variants per window)
# [INFO] Processed 296 of 3400 windows
# [INFO] Skipped window 2960001-3960000 with 49 variants (threshold is 50 variants per window)
# [INFO] Processed 297 of 3400 windows
# [INFO] Skipped window 2970001-3970000 with 49 variants (threshold is 50 variants per window)
# [INFO] Processed 298 of 3400 windows
# [INFO] Skipped window 2980001-3980000 with 49 variants (threshold is 50 variants per window)
# [INFO] Processed 299 of 3400 windows
# [INFO] Skipped window 2990001-3990000 with 48 variants (threshold is 50 variants per window)
# [INFO] Processed 300 of 3400 windows
# [INFO] Skipped window 3000001-4000000 with 47 variants (threshold is 50 variants per window)
# [INFO] Processed 301 of 3400 windows
# [INFO] Skipped window 3010001-4010000 with 46 variants (threshold is 50 variants per window)
# [INFO] Processed 302 of 3400 windows
# [INFO] Skipped window 3020001-4020000 with 45 variants (threshold is 50 variants per window)
# [INFO] Processed 303 of 3400 windows
# [INFO] Skipped window 3030001-4030000 with 43 variants (threshold is 50 variants per window)
# [INFO] Processed 304 of 3400 windows
# [INFO] Skipped window 3040001-4040000 with 40 variants (threshold is 50 variants per window)
# [INFO] Processed 305 of 3400 windows
# [INFO] Skipped window 3050001-4050000 with 40 variants (threshold is 50 variants per window)
# [INFO] Processed 306 of 3400 windows
# [INFO] Skipped window 3060001-4060000 with 40 variants (threshold is 50 variants per window)
# [INFO] Processed 307 of 3400 windows
# [INFO] Skipped window 3070001-4070000 with 40 variants (threshold is 50 variants per window)
# [INFO] Processed 308 of 3400 windows
# [INFO] Skipped window 3080001-4080000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 309 of 3400 windows
# [INFO] Skipped window 3090001-4090000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 310 of 3400 windows
# [INFO] Skipped window 3100001-4100000 with 35 variants (threshold is 50 variants per window)
# [INFO] Processed 311 of 3400 windows
# [INFO] Skipped window 3110001-4110000 with 35 variants (threshold is 50 variants per window)
# [INFO] Processed 312 of 3400 windows
# [INFO] Skipped window 3120001-4120000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 313 of 3400 windows
# [INFO] Skipped window 3130001-4130000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 314 of 3400 windows
# [INFO] Skipped window 3140001-4140000 with 34 variants (threshold is 50 variants per window)
# [INFO] Processed 315 of 3400 windows
# [INFO] Skipped window 3150001-4150000 with 35 variants (threshold is 50 variants per window)
# [INFO] Processed 316 of 3400 windows
# [INFO] Skipped window 3160001-4160000 with 35 variants (threshold is 50 variants per window)
# [INFO] Processed 317 of 3400 windows
# [INFO] Skipped window 3170001-4170000 with 37 variants (threshold is 50 variants per window)
# [INFO] Processed 318 of 3400 windows
# [INFO] Skipped window 3180001-4180000 with 37 variants (threshold is 50 variants per window)
# [INFO] Processed 319 of 3400 windows
# [INFO] Skipped window 3190001-4190000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 320 of 3400 windows
# [INFO] Skipped window 3200001-4200000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 321 of 3400 windows
# [INFO] Skipped window 3210001-4210000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 322 of 3400 windows
# [INFO] Skipped window 3220001-4220000 with 37 variants (threshold is 50 variants per window)
# [INFO] Processed 323 of 3400 windows
# [INFO] Skipped window 3230001-4230000 with 37 variants (threshold is 50 variants per window)
# [INFO] Processed 324 of 3400 windows
# [INFO] Skipped window 3240001-4240000 with 37 variants (threshold is 50 variants per window)
# [INFO] Processed 325 of 3400 windows
# [INFO] Skipped window 3250001-4250000 with 36 variants (threshold is 50 variants per window)
# [INFO] Processed 326 of 3400 windows
# [INFO] Skipped window 3260001-4260000 with 37 variants (threshold is 50 variants per window)
# [INFO] Processed 327 of 3400 windows
# [INFO] Skipped window 3270001-4270000 with 38 variants (threshold is 50 variants per window)
# [INFO] Processed 328 of 3400 windows
# [INFO] Skipped window 3280001-4280000 with 39 variants (threshold is 50 variants per window)
# [INFO] Processed 329 of 3400 windows
# [INFO] Skipped window 3290001-4290000 with 41 variants (threshold is 50 variants per window)
# [INFO] Processed 330 of 3400 windows
# [INFO] Skipped window 3300001-4300000 with 42 variants (threshold is 50 variants per window)
# [INFO] Processed 331 of 3400 windows
# [INFO] Skipped window 3310001-4310000 with 42 variants (threshold is 50 variants per window)
# [INFO] Processed 332 of 3400 windows
# [INFO] Skipped window 3320001-4320000 with 42 variants (threshold is 50 variants per window)
# [INFO] Processed 333 of 3400 windows
# [INFO] Skipped window 3330001-4330000 with 42 variants (threshold is 50 variants per window)
# [INFO] Processed 334 of 3400 windows
# [INFO] Skipped window 3340001-4340000 with 45 variants (threshold is 50 variants per window)
# [INFO] Processed 335 of 3400 windows
# [INFO] Skipped window 3350001-4350000 with 45 variants (threshold is 50 variants per window)
# [INFO] Processed 336 of 3400 windows
# [INFO] Skipped window 3360001-4360000 with 45 variants (threshold is 50 variants per window)
# [INFO] Processed 337 of 3400 windows
# [INFO] Skipped window 3370001-4370000 with 45 variants (threshold is 50 variants per window)
# [INFO] Processed 338 of 3400 windows
# [INFO] Skipped window 3380001-4380000 with 44 variants (threshold is 50 variants per window)
# [INFO] Processed 339 of 3400 windows
# [INFO] Skipped window 3390001-4390000 with 43 variants (threshold is 50 variants per window)
# [INFO] Processed 340 of 3400 windows
# [INFO] Skipped window 3400001-4400000 with 42 variants (threshold is 50 variants per window)
# [INFO] Processed 341 of 3400 windows
# [INFO] Skipped window 3410001-4410000 with 42 variants (threshold is 50 variants per window)
# [INFO] Processed 342 of 3400 windows
# [INFO] Skipped window 3420001-4420000 with 41 variants (threshold is 50 variants per window)
# [INFO] Processed 343 of 3400 windows
# [INFO] Skipped window 3430001-4430000 with 40 variants (threshold is 50 variants per window)
# [INFO] Processed 344 of 3400 windows
# [INFO] Skipped window 3440001-4440000 with 40 variants (threshold is 50 variants per window)
# [INFO] Processed 345 of 3400 windows
# [INFO] Skipped window 3450001-4450000 with 41 variants (threshold is 50 variants per window)
# [INFO] Processed 346 of 3400 windows
# [INFO] Skipped window 3460001-4460000 with 41 variants (threshold is 50 variants per window)
# [INFO] Processed 347 of 3400 windows
# [INFO] Skipped window 3470001-4470000 with 42 variants (threshold is 50 variants per window)
# [INFO] Processed 348 of 3400 windows
# [INFO] Skipped window 3480001-4480000 with 43 variants (threshold is 50 variants per window)
# [INFO] Processed 349 of 3400 windows
# [INFO] Skipped window 3490001-4490000 with 44 variants (threshold is 50 variants per window)
# [INFO] Processed 350 of 3400 windows
# [INFO] Skipped window 3500001-4500000 with 45 variants (threshold is 50 variants per window)
# [INFO] Processed 351 of 3400 windows
# [INFO] Skipped window 3510001-4510000 with 46 variants (threshold is 50 variants per window)
# [INFO] Processed 352 of 3400 windows
# [INFO] Skipped window 3520001-4520000 with 49 variants (threshold is 50 variants per window)
# [INFO] Processed 353 of 3400 windows
# [INFO] Processed 354 of 3400 windows
# [INFO] Processed 355 of 3400 windows
# [INFO] Processed 356 of 3400 windows
# [INFO] Skipped window 3560001-4560000 with 50 variants (threshold is 50 variants per window)
# [INFO] Processed 357 of 3400 windows
# [INFO] Skipped window 3570001-4570000 with 50 variants (threshold is 50 variants per window)
# [INFO] Processed 358 of 3400 windows
# [INFO] Processed 359 of 3400 windows
# [INFO] Processed 360 of 3400 windows
# [INFO] Processed 361 of 3400 windows
# [INFO] Processed 362 of 3400 windows
# [INFO] Processed 363 of 3400 windows
# [INFO] Processed 364 of 3400 windows
# [INFO] Processed 365 of 3400 windows
# [INFO] Processed 366 of 3400 windows
# [INFO] Processed 367 of 3400 windows
# [INFO] Processed 368 of 3400 windows
# [INFO] Processed 369 of 3400 windows
# [INFO] Processed 370 of 3400 windows
# [INFO] Processed 371 of 3400 windows
# [INFO] Processed 372 of 3400 windows
# [INFO] Processed 373 of 3400 windows
# [INFO] Processed 374 of 3400 windows
# [INFO] Processed 375 of 3400 windows
# [INFO] Processed 376 of 3400 windows
# [INFO] Processed 377 of 3400 windows
# [INFO] Processed 378 of 3400 windows
# [INFO] Processed 379 of 3400 windows
# [INFO] Processed 380 of 3400 windows
# [INFO] Processed 381 of 3400 windows
# [INFO] Processed 382 of 3400 windows
# [INFO] Processed 383 of 3400 windows
# [INFO] Processed 384 of 3400 windows
# [INFO] Processed 385 of 3400 windows
# [INFO] Processed 386 of 3400 windows
# [INFO] Processed 387 of 3400 windows
# [INFO] Processed 388 of 3400 windows
# [INFO] Processed 389 of 3400 windows
# [INFO] Processed 390 of 3400 windows
# [INFO] Processed 391 of 3400 windows
# [INFO] Processed 392 of 3400 windows
# [INFO] Processed 393 of 3400 windows
# [INFO] Processed 394 of 3400 windows
# [INFO] Processed 395 of 3400 windows
# [INFO] Processed 396 of 3400 windows
# [INFO] Processed 397 of 3400 windows
# [INFO] Processed 398 of 3400 windows
# [INFO] Processed 399 of 3400 windows
# 6   1.622347   1.396324   1.365279  ...   9.471174   9.650515   9.650515
# 7  10.575745  10.190557  10.183208  ...  12.540736  12.780464  12.780464
# 8  15.610721  15.892811  15.891883  ...   6.915030   6.585533   6.585533
#
#     34430000   34440000   34450000   34460000   34470000   34480000   34490000
# 0  -7.005031  -7.005031  -6.988921  -6.678020  -6.758723  -7.085608  -7.141663
# 1  -6.193985  -6.193985  -6.187108  -6.147841  -6.072806  -6.415628  -6.344414
# 2  -4.909713  -4.909713  -4.875697  -4.898950  -4.858013  -4.812290  -4.743016
# 3  -4.123552  -4.123552  -4.082880  -4.122310  -4.107224  -4.079080  -4.072603
# 4  -1.651030  -1.651030  -1.624317  -1.386471  -1.217824  -1.337254  -1.202189
# 5  -4.893957  -4.893957  -4.790757  -5.186701  -5.279856  -4.183340  -4.156359
# 6   9.670851   9.670851   9.679150  10.511088  11.306049  11.340399  11.995109
# 7  13.041508  13.041508  13.262346  11.375856  10.105575   9.762806   8.629258
# 8   6.062639   6.062639   5.605974   6.530861   6.880184   6.807981   7.033758
#
# [9 rows x 3401 columns]

# %%
w_pca_df.to_csv(w_pca_tsv_path + '_2', sep='\t', compression='gzip')

# %%
w_pca_df.isnull().values.any()
# Out:
# True

# %%
w_stats_df
# Out:
#             pct_explained_pc_1  pct_explained_pc_2  num_variants  \
# window_mid
# 500000               24.752402           19.138455           118
# 510000               24.752402           19.138455           118
# 520000               24.752201           19.575846           119
# 530000               24.752201           19.575846           119
# 540000               24.752201           19.575846           119
# ...                        ...                 ...           ...
# 34450000             22.322288           17.913805           113
# 34460000             22.104089           17.136005           109
# 34470000             22.035465           16.730970           108
# 34480000             22.303078           17.008805           105
# 34490000             22.299655           16.544101           104
#
#             pct_included_sites
# window_mid
# 500000                0.000001
# 510000                0.000001
# 520000                0.000001
# 530000                0.000001
# 540000                0.000001
# ...                        ...
# 34450000              0.000001
# 34460000              0.000001
# 34470000              0.000001
# 34480000              0.000001
# 34490000              0.000001
#
# [3400 rows x 4 columns]

# %%
w_stats_tsv_path =      output_prefix + '.w_stats'          + '.tsv.gz'
w_stats_df_2 = pd.read_csv(w_stats_tsv_path,  sep='\t', index_col=0, na_values='NA')
w_stats_df_2
# Out:
#             pct_explained_pc_1  pct_explained_pc_2  num_variants  \
# window_mid
# 500000               24.752402           19.138455           118
# 510000               24.752402           19.138455           118
# 520000               24.752201           19.575846           119
# 530000               24.752201           19.575846           119
# 540000               24.752201           19.575846           119
# ...                        ...                 ...           ...
# 34450000             22.322288           17.913805           113
# 34460000             22.104089           17.136005           109
# 34470000             22.035465           16.730970           108
# 34480000             22.303078           17.008805           105
# 34490000             22.299655           16.544101           104
#
#             pct_included_sites
# window_mid
# 500000                0.000001
# 510000                0.000001
# 520000                0.000001
# 530000                0.000001
# 540000                0.000001
# ...                        ...
# 34450000              0.000001
# 34460000              0.000001
# 34470000              0.000001
# 34480000              0.000001
# 34490000              0.000001
#
# [3400 rows x 4 columns]
