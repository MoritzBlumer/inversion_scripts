# %%
#!/usr/bin/env python
#
# Moritz Blumer | 2021-12-07 (2023-03-15)
#
# Conduct sliding window PCA with scikit-allel 



# produces identical results to previous version (except window boundaries)

#### ADD PC SELECTION, AND REMOVE PC2 FUNCTIONALITY (--> to be run with whatever PC)

#### IMPROVE READING EXISTING OUTPUT (SAVE UNANNOTATED?)

#### NUMBA?

#### FIX PCT INCLUDED SITES SCALE; ABRUNDEN PC % EXP VALUES

# To add PC2 output, uncomment lines tagged with '# uncomment for PC 2'

# add check whether input samples are unique (if not len(set(input_salmpes)) == ...)

# change documentation: 'primary_id' --> 'id' (maybe change to 'sample_id')

# PLOTTING SHOULDN'T START AT 0 BUT WINDOW MID!




# The minimum number of variants per window is set to 50 and can be changed below (NA will be returned for windows with fewer variants)
min_var_per_window = 50

# import packages

import allel
import gzip
import sys
import numpy as np
import pandas as pd
#import numba as nb

# %%
# set arguments
variant_file_path = '../test_dataset/input/genotype_file.tsv.gz'
#variant_file_path = '../test_dataset/input/sample.vcf'
metadata_path = '../test_dataset/input/metadata.tsv'
var_threshold = 9 # make set inbsteat of option
mean_threshold = 3
chrom = 'chr1'
pc=1
skip_monomorphic = True
output_prefix = 'test_out'
output_prefix = output_prefix.lower()
color_taxon = 'inversion_state'
w_size = 1000000
w_step = 10000
region = '10000000-20000000'
start = int(region.split('-')[0])
stop = int(region.split('-')[1])

# %%
## GET RID OF ORDER BY GT FILE, OR NOT? --> TEST IF CURRENT VERSION CAUSES PROBLEMS

# read metadata

def read_metadata(variant_file_path, metadata_path, taxon=None, group=None):
    '''
    Read in metadata, optionally filter by taxon and sort by gt_file sample order

    '''

    # fetch sample names from genotype file header
    read_func = gzip.open if variant_file_path.endswith('.gz') else open
    with read_func(variant_file_path, 'rt') as gt_file:
        samples_lst = gt_file.readline().strip().split('\t')[2:]

    # read in metadata
    metadata_df = pd.read_csv(metadata_path, sep='\t')

    # re-name first column to 'id' (this is the only required column and must have unique ids)
    metadata_df.columns.values[0] = 'id'

    # subset input samples to match taxon group specification if specified
    if taxon and group:
        metadata_df = metadata_df.loc[metadata_df[taxon].isin(group.split(','))]
    
    # remove individuals that are not in the genotype file
    exclude_lst = [x for x in list(metadata_df['id']) if x not in samples_lst]
    for i in exclude_lst:
        metadata_df.drop(metadata_df[metadata_df['id'] == i].index, inplace=True)
    
    # # get index of samples kept after filtering
    # sample_idx_lst = sorted([samples_lst.index(x) for x in list(metadata_df['id'])])
    # keep_id_lst = [samples_lst[x] for x in sample_idx_lst]

    # # sort metadata by VCF sample order 
    # metadata_df['id'] = pd.Categorical(metadata_df['id'], categories = keep_id_lst, ordered = True)
    # metadata_df.sort_values('id', inplace=True)

    return metadata_df

metadata_df = read_metadata(variant_file_path, metadata_path, taxon='species', group='species_1,species_2')


def pca(win, w_start, w_size):
    '''
    Conduct PCA, but if ((n_variants < min_var_per_window)) generate empty/dummy output instead
    '''

    # trim off pos info
    win = [x[1:] for x in win]

    # get window mid for X value
    w_mid = int(w_start + w_size/2-1)

    # count variants
    n_variants = len(win)

    # if # variants passes specified threshold  
    if n_variants > min_var_per_window: # CHANGE TO: "if n_variants >= min_var_per_window:" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        w_gt_arr = np.array(win, dtype=np.int8)
        pca = allel.pca(w_gt_arr, n_components=2, copy=True, scaler='patterson', ploidy=2)
        out = [pca[0][: , 0], pca[0][: , 1], pca[1].explained_variance_ratio_[0]*100, pca[1].explained_variance_ratio_[1]*100, n_variants]

    # else create empty output
    else:
        print('[INFO] Skipped window ' + str(w_start) + '-' + str(w_start + w_size-1) + ' with ' + str(n_variants) + ' variants (threshold is ' + str(min_var_per_window) + ' variants per window)', file=sys.stderr, flush=True)
        empty_array = [None] * len(win[0])
        out = [empty_array, empty_array, None, None, n_variants]

    # append output
    w_mid_lst.append(w_mid)
    w_pca_lst.append(out[0]) if pc==1 else out[1] # depending on whether PC1 or PC2 was specified, append out[0] or out[1], respectively
    w_stats_lst.append([out[2], out[3], out[4]])


# frame for window-by-window analysis
def windowed_pca(variant_file_path, chrom, start, stop, metadata_df, pca, w_size, w_step, skip_monomorphic=True):

    global w_mid_lst, w_pca_lst, w_stats_lst

    # # initialize results containers
    w_mid_lst = []
    w_pca_lst = []
    w_stats_lst = []

    # # conduct windowed PCA using window_parser() function
    if variant_file_path.endswith('.vcf') or variant_file_path.endswith('.vcf.gz'):
        from window_parser import win_vcf
        win_vcf(variant_file_path, chrom, start, stop, metadata_df['id'], w_size, w_step, pca, skip_monomorphic=skip_monomorphic)

    elif variant_file_path.endswith('.tsv') or variant_file_path.endswith('.tsv.gz'):
        from window_parser import win_gt_file
        win_gt_file(variant_file_path, chrom, start, stop, metadata_df['id'], w_size, w_step, pca, skip_monomorphic=skip_monomorphic)

    # compile output dataframe for windowed PCA
    w_pca_df = pd.DataFrame(np.transpose(w_pca_lst), index=list(metadata_df['id']), columns=w_mid_lst)
    w_pca_df.index.names = ['id']

    # compile output dataframe for supplementary info (% variance explained, # sites per window)
    w_stats_df = pd.DataFrame(w_stats_lst, index=w_mid_lst, columns=['pct_explained_pc_1', 'pct_explained_pc_2', 'num_variants'])
    w_stats_df.index.names = ['window_mid']
    w_stats_df['pct_included_sites'] = w_stats_df['num_variants']/w_size/100

    return w_pca_df, w_stats_df

w_pca_df, w_stats_df = windowed_pca(variant_file_path, chrom, start, stop, metadata_df, pca, w_size, w_step, skip_monomorphic)


# polarize windowed PCA output
def polarize(w_pca_df, var_threshold=9, mean_threshold=3): ## IMPROVE GUIDESAMPLE SETTINGS

    '''
    - take a w_pca_df and adjust window orientation using a selection of a few samples with high absolute values and small variability
    - then annotate the df with metadata.
    - hack: if setting var_threshold=False and mean_threshold to a list of ids (e.g. "cichlid7050764,cichlid7050776,cichlid7050768"), those will be used as guide samples for polarizaion
    '''

    # select the 9 samples with the least variance, and from those the 3 with the highest absolute value accross 
    # all windows as guide samples to calibrate the orientation of all windows

    if not var_threshold == 'False':
        guide_samples = list(w_pca_df.dropna(axis=1).abs().var(axis=1).sort_values(ascending=True).index[0:var_threshold])
        guide_samples_df = w_pca_df.loc[guide_samples]
        guide_samples = list(guide_samples_df.dropna(axis=1).abs().sum(axis=1).sort_values(ascending=False).index[0:mean_threshold])

    else:
        guide_samples = mean_threshold.split(',')
        guide_samples_df = w_pca_df.loc[guide_samples]

    guide_samples_df = guide_samples_df.loc[guide_samples]

    # for each guide sample, determine whether the positive or negative absolute value of each window is closer 
    # to the value in the previous window. If the negative value is closer, switch that windows orientation
    # (1 --> switch, 0 --> keep)
    
    rows_lst = []    
    for row in guide_samples_df.iterrows():
        row = list(row[1])
        last_window = row[0] if not row[0] == None else 0 # only if the first window is None, last_window can be None, in that case set it to 0 to enable below numerical comparisons
        out = [0]
    
        for window in row[1:]:
            if window == None:
                out.append(0)
                continue
    
            elif abs(window - last_window) > abs(window - (last_window*-1)):
                out.append(1)
                last_window = (window*-1)
    
            else:
                out.append(-1)
                last_window = window
    
        rows_lst.append(out)

    # sum up values from each row and save to switch_lst
    rows_arr = np.array(rows_lst, dtype=int).transpose()
    switch_lst = list(rows_arr.sum(axis=1))

    # switch individual windows according to switch_lst (switch if value is negative)
    for idx, val in zip(list(w_pca_df.columns), switch_lst):
        if val < 0:
            w_pca_df[idx] = w_pca_df[idx]*-1

    # switch Y axis if largest absolute value is negative
    if abs(w_pca_df.to_numpy(na_value=0).min()) > abs(w_pca_df.to_numpy(na_value=0).max()):
        w_pca_df = w_pca_df * -1

    return w_pca_df

w_pca_df = polarize(w_pca_df, var_threshold=9, mean_threshold=3)


# save output data before annotation
w_pca_df.to_csv(output_prefix + '.w_pc_' + str(pc) + '.tsv.gz', sep='\t', compression='gzip')
w_stats_df.to_csv(output_prefix + '.w_stats.tsv.gz', sep='\t', compression='gzip')

# pivot & annotate windowed pca output
def annotate(w_pca_df, metadata_df, pc):

    # annotate with metadata
    for column_name in metadata_df.columns:
        w_pca_df[column_name] = list(metadata_df[column_name])

    # replace numpy NaN with 'NA' for plotting (hover_data display)
    w_pca_df = w_pca_df.replace(np.nan, 'NA')

    # convert to long format for plotting
    w_pca_df_annotated = pd.melt(w_pca_df, id_vars=metadata_df.columns, var_name='window_mid', value_name=pc)

    return w_pca_df_annotated

pc_anno_df = annotate(w_pca_df, metadata_df, 'pc_' + str(pc))

# plot windowed PCA output & save
from utils import plot_w_pca
w_pca_fig = plot_w_pca(pc_anno_df, 1, color_taxon, chrom, start, stop, w_size, w_step)
w_pca_fig.write_html(output_prefix + '.w_pc_' + str(pc) + '.html')
w_pca_fig.write_image(output_prefix + '.w_pc_' + str(pc) + '.pdf', engine='kaleido', scale=2.4)

# plot window stats & save
from utils import plot_w_stats
w_stats_fig = plot_w_stats(w_stats_df, chrom, start, stop, w_size, w_step)
w_stats_fig.write_html(output_prefix + '.w_stats' + '.html')
w_stats_fig.write_image(output_prefix + '.w_stats' + '.pdf', engine='kaleido', scale=2.4)
# Out:
# [INFO] Processed 1 of 901 windows
# [INFO] Processed 2 of 901 windows
# [INFO] Processed 3 of 901 windows
# [INFO] Processed 4 of 901 windows
# [INFO] Processed 5 of 901 windows
# [INFO] Processed 6 of 901 windows
# [INFO] Processed 7 of 901 windows
# [INFO] Processed 8 of 901 windows
# [INFO] Processed 9 of 901 windows
# [INFO] Processed 10 of 901 windows
# [INFO] Processed 11 of 901 windows
# [INFO] Processed 12 of 901 windows
# [INFO] Processed 13 of 901 windows
# [INFO] Processed 14 of 901 windows
# [INFO] Processed 15 of 901 windows
# [INFO] Processed 16 of 901 windows
# [INFO] Processed 17 of 901 windows
# [INFO] Processed 18 of 901 windows
# [INFO] Processed 19 of 901 windows
# [INFO] Processed 20 of 901 windows
# [INFO] Processed 21 of 901 windows
# [INFO] Processed 22 of 901 windows
# [INFO] Processed 23 of 901 windows
# [INFO] Processed 24 of 901 windows
# [INFO] Processed 25 of 901 windows
# [INFO] Processed 26 of 901 windows
# [INFO] Processed 27 of 901 windows
# [INFO] Processed 28 of 901 windows
# [INFO] Processed 29 of 901 windows
# [INFO] Processed 30 of 901 windows
# [INFO] Processed 31 of 901 windows
# [INFO] Processed 32 of 901 windows
# [INFO] Processed 33 of 901 windows
# [INFO] Processed 34 of 901 windows
# [INFO] Processed 35 of 901 windows
# [INFO] Processed 36 of 901 windows
# [INFO] Processed 37 of 901 windows
# [INFO] Processed 38 of 901 windows
# [INFO] Processed 39 of 901 windows
# [INFO] Processed 40 of 901 windows
# [INFO] Processed 41 of 901 windows
# [INFO] Processed 42 of 901 windows
# [INFO] Processed 43 of 901 windows
# [INFO] Processed 44 of 901 windows
# [INFO] Processed 45 of 901 windows
# [INFO] Processed 46 of 901 windows
# [INFO] Processed 47 of 901 windows
# [INFO] Processed 48 of 901 windows
# [INFO] Processed 49 of 901 windows
# [INFO] Processed 50 of 901 windows
# [INFO] Processed 51 of 901 windows
# [INFO] Processed 52 of 901 windows
# [INFO] Processed 53 of 901 windows
# [INFO] Processed 54 of 901 windows
# [INFO] Processed 55 of 901 windows
# [INFO] Processed 56 of 901 windows
# [INFO] Processed 57 of 901 windows
# [INFO] Processed 58 of 901 windows
# [INFO] Processed 59 of 901 windows
# [INFO] Processed 60 of 901 windows
# [INFO] Processed 61 of 901 windows
# [INFO] Processed 62 of 901 windows
# [INFO] Processed 63 of 901 windows
# [INFO] Processed 64 of 901 windows
# [INFO] Processed 65 of 901 windows
# [INFO] Processed 66 of 901 windows
# [INFO] Processed 67 of 901 windows
# [INFO] Processed 68 of 901 windows
# [INFO] Processed 69 of 901 windows
# [INFO] Processed 70 of 901 windows
# [INFO] Processed 71 of 901 windows
# [INFO] Processed 72 of 901 windows
# [INFO] Processed 73 of 901 windows
# [INFO] Processed 74 of 901 windows
# [INFO] Processed 75 of 901 windows
# [INFO] Processed 76 of 901 windows
# [INFO] Processed 77 of 901 windows
# [INFO] Processed 78 of 901 windows
# [INFO] Processed 79 of 901 windows
# [INFO] Processed 80 of 901 windows
# [INFO] Processed 81 of 901 windows
# [INFO] Processed 82 of 901 windows
# [INFO] Processed 83 of 901 windows
# [INFO] Processed 84 of 901 windows
# [INFO] Processed 85 of 901 windows
# [INFO] Processed 86 of 901 windows
# [INFO] Processed 87 of 901 windows
# [INFO] Processed 88 of 901 windows
# [INFO] Processed 89 of 901 windows
# [INFO] Processed 90 of 901 windows
# [INFO] Processed 91 of 901 windows
# [INFO] Processed 92 of 901 windows
# [INFO] Processed 93 of 901 windows
# [INFO] Processed 94 of 901 windows
# [INFO] Processed 95 of 901 windows
# [INFO] Processed 96 of 901 windows
# [INFO] Processed 97 of 901 windows
# [INFO] Processed 98 of 901 windows
# [INFO] Processed 99 of 901 windows
# [INFO] Processed 100 of 901 windows
# [INFO] Processed 101 of 901 windows
# [INFO] Processed 102 of 901 windows
# [INFO] Processed 103 of 901 windows
# [INFO] Processed 104 of 901 windows
# [INFO] Processed 105 of 901 windows
# [INFO] Processed 106 of 901 windows
# [INFO] Processed 107 of 901 windows
# [INFO] Processed 108 of 901 windows
# [INFO] Processed 109 of 901 windows
# [INFO] Processed 110 of 901 windows
# [INFO] Processed 111 of 901 windows
# [INFO] Processed 112 of 901 windows
# [INFO] Processed 113 of 901 windows
# [INFO] Processed 114 of 901 windows
# [INFO] Processed 115 of 901 windows
# [INFO] Processed 116 of 901 windows
# [INFO] Processed 117 of 901 windows
# [INFO] Processed 118 of 901 windows
# [INFO] Processed 119 of 901 windows
# [INFO] Processed 120 of 901 windows
# [INFO] Processed 121 of 901 windows
# [INFO] Processed 122 of 901 windows
# [INFO] Processed 123 of 901 windows
# [INFO] Processed 124 of 901 windows
# [INFO] Processed 125 of 901 windows
# [INFO] Processed 126 of 901 windows
# [INFO] Processed 127 of 901 windows
# [INFO] Processed 128 of 901 windows
# [INFO] Processed 129 of 901 windows
# [INFO] Processed 130 of 901 windows
# [INFO] Processed 131 of 901 windows
# [INFO] Processed 132 of 901 windows
# [INFO] Processed 133 of 901 windows
# [INFO] Processed 134 of 901 windows
# [INFO] Processed 135 of 901 windows
# [INFO] Processed 136 of 901 windows
# [INFO] Processed 137 of 901 windows
# [INFO] Processed 138 of 901 windows
# [INFO] Processed 139 of 901 windows
# [INFO] Processed 140 of 901 windows
# [INFO] Processed 141 of 901 windows
# [INFO] Processed 142 of 901 windows
# [INFO] Processed 143 of 901 windows
# [INFO] Processed 144 of 901 windows
# [INFO] Processed 145 of 901 windows
# [INFO] Processed 146 of 901 windows
# [INFO] Processed 147 of 901 windows
# [INFO] Processed 148 of 901 windows
# [INFO] Processed 149 of 901 windows
# [INFO] Processed 150 of 901 windows
# [INFO] Processed 151 of 901 windows
# [INFO] Processed 152 of 901 windows
# [INFO] Processed 153 of 901 windows
# [INFO] Processed 154 of 901 windows
# [INFO] Processed 155 of 901 windows
# [INFO] Processed 156 of 901 windows
# [INFO] Processed 157 of 901 windows
# [INFO] Processed 158 of 901 windows
# [INFO] Processed 159 of 901 windows
# [INFO] Processed 160 of 901 windows
# [INFO] Processed 161 of 901 windows
# [INFO] Processed 162 of 901 windows
# [INFO] Processed 163 of 901 windows
# [INFO] Processed 164 of 901 windows
# [INFO] Processed 165 of 901 windows
# [INFO] Processed 166 of 901 windows
# [INFO] Processed 167 of 901 windows
# [INFO] Processed 168 of 901 windows
# [INFO] Processed 169 of 901 windows
# [INFO] Processed 170 of 901 windows
# [INFO] Processed 171 of 901 windows
# [INFO] Processed 172 of 901 windows
# [INFO] Processed 173 of 901 windows
# [INFO] Processed 174 of 901 windows
# [INFO] Processed 175 of 901 windows
# [INFO] Processed 176 of 901 windows
# [INFO] Processed 177 of 901 windows
# [INFO] Processed 178 of 901 windows
# [INFO] Processed 179 of 901 windows
# [INFO] Processed 180 of 901 windows
# [INFO] Processed 181 of 901 windows
# [INFO] Processed 182 of 901 windows
# [INFO] Processed 183 of 901 windows
# [INFO] Processed 184 of 901 windows
# [INFO] Processed 185 of 901 windows
# [INFO] Processed 186 of 901 windows
# [INFO] Processed 187 of 901 windows
# [INFO] Processed 188 of 901 windows
# [INFO] Processed 189 of 901 windows
# [INFO] Processed 190 of 901 windows
# [INFO] Processed 191 of 901 windows
# [INFO] Processed 192 of 901 windows
# [INFO] Processed 193 of 901 windows
# [INFO] Processed 194 of 901 windows
# [INFO] Processed 195 of 901 windows
# [INFO] Processed 196 of 901 windows
# [INFO] Processed 197 of 901 windows
# [INFO] Processed 198 of 901 windows
# [INFO] Processed 199 of 901 windows
# [INFO] Processed 200 of 901 windows
# [INFO] Processed 201 of 901 windows
# [INFO] Processed 202 of 901 windows
# [INFO] Processed 203 of 901 windows
# [INFO] Processed 204 of 901 windows
# [INFO] Processed 205 of 901 windows
# [INFO] Processed 206 of 901 windows
# [INFO] Processed 207 of 901 windows
# [INFO] Processed 208 of 901 windows
# [INFO] Processed 209 of 901 windows
# [INFO] Processed 210 of 901 windows
# [INFO] Processed 211 of 901 windows
# [INFO] Processed 212 of 901 windows
# [INFO] Processed 213 of 901 windows
# [INFO] Processed 214 of 901 windows
# [INFO] Processed 215 of 901 windows
# [INFO] Processed 216 of 901 windows
# [INFO] Processed 217 of 901 windows
# [INFO] Processed 218 of 901 windows
# [INFO] Processed 219 of 901 windows
# [INFO] Processed 220 of 901 windows
# [INFO] Processed 221 of 901 windows
# [INFO] Processed 222 of 901 windows
# [INFO] Processed 223 of 901 windows
# [INFO] Processed 224 of 901 windows
# [INFO] Processed 225 of 901 windows
# [INFO] Processed 226 of 901 windows
# [INFO] Processed 227 of 901 windows
# [INFO] Processed 228 of 901 windows
# [INFO] Processed 229 of 901 windows
# [INFO] Processed 230 of 901 windows
# [INFO] Processed 231 of 901 windows
# [INFO] Processed 232 of 901 windows
# [INFO] Processed 233 of 901 windows
# [INFO] Processed 234 of 901 windows
# [INFO] Processed 235 of 901 windows
# [INFO] Processed 236 of 901 windows
# [INFO] Processed 237 of 901 windows
# [INFO] Processed 238 of 901 windows
# [INFO] Processed 239 of 901 windows
# [INFO] Processed 240 of 901 windows
# [INFO] Processed 241 of 901 windows
# [INFO] Processed 242 of 901 windows
# [INFO] Processed 243 of 901 windows
# [INFO] Processed 244 of 901 windows
# [INFO] Processed 245 of 901 windows
# [INFO] Processed 246 of 901 windows
# [INFO] Processed 247 of 901 windows
# [INFO] Processed 248 of 901 windows
# [INFO] Processed 249 of 901 windows
# [INFO] Processed 250 of 901 windows
# [INFO] Processed 251 of 901 windows
# [INFO] Processed 252 of 901 windows
# [INFO] Processed 253 of 901 windows
# [INFO] Processed 254 of 901 windows
# [INFO] Processed 255 of 901 windows
# [INFO] Processed 256 of 901 windows
# [INFO] Processed 257 of 901 windows
# [INFO] Processed 258 of 901 windows
# [INFO] Processed 259 of 901 windows
# [INFO] Processed 260 of 901 windows
# [INFO] Processed 261 of 901 windows
# [INFO] Processed 262 of 901 windows
# [INFO] Processed 263 of 901 windows
# [INFO] Processed 264 of 901 windows
# [INFO] Processed 265 of 901 windows
# [INFO] Processed 266 of 901 windows
# [INFO] Processed 267 of 901 windows
# [INFO] Processed 268 of 901 windows
# [INFO] Processed 269 of 901 windows
# [INFO] Processed 270 of 901 windows
# [INFO] Processed 271 of 901 windows
# [INFO] Processed 272 of 901 windows
# [INFO] Processed 273 of 901 windows
# [INFO] Processed 274 of 901 windows
# [INFO] Processed 275 of 901 windows
# [INFO] Processed 276 of 901 windows
# [INFO] Processed 277 of 901 windows
# [INFO] Processed 278 of 901 windows
# [INFO] Processed 279 of 901 windows
# [INFO] Processed 280 of 901 windows
# [INFO] Processed 281 of 901 windows
# [INFO] Processed 282 of 901 windows
# [INFO] Processed 283 of 901 windows
# [INFO] Processed 284 of 901 windows
# [INFO] Processed 285 of 901 windows
# [INFO] Processed 286 of 901 windows
# [INFO] Processed 287 of 901 windows
# [INFO] Processed 288 of 901 windows
# [INFO] Processed 289 of 901 windows
# [INFO] Processed 290 of 901 windows
# [INFO] Processed 291 of 901 windows
# [INFO] Processed 292 of 901 windows
# [INFO] Processed 293 of 901 windows
# [INFO] Processed 294 of 901 windows
# [INFO] Processed 295 of 901 windows
# [INFO] Processed 296 of 901 windows
# [INFO] Processed 297 of 901 windows
# [INFO] Processed 298 of 901 windows
# [INFO] Processed 299 of 901 windows
# [INFO] Processed 300 of 901 windows
# [INFO] Processed 301 of 901 windows
# [INFO] Processed 302 of 901 windows
# [INFO] Processed 303 of 901 windows
# [INFO] Processed 304 of 901 windows
# [INFO] Processed 305 of 901 windows
# [INFO] Processed 306 of 901 windows
# [INFO] Processed 307 of 901 windows
# [INFO] Processed 308 of 901 windows
# [INFO] Processed 309 of 901 windows
# [INFO] Processed 310 of 901 windows
# [INFO] Processed 311 of 901 windows
# [INFO] Processed 312 of 901 windows
# [INFO] Processed 313 of 901 windows
# [INFO] Processed 314 of 901 windows
# [INFO] Processed 315 of 901 windows
# [INFO] Processed 316 of 901 windows
# [INFO] Processed 317 of 901 windows
# [INFO] Processed 318 of 901 windows
# [INFO] Processed 319 of 901 windows
# [INFO] Processed 320 of 901 windows
# [INFO] Processed 321 of 901 windows
# [INFO] Processed 322 of 901 windows
# [INFO] Processed 323 of 901 windows
# [INFO] Processed 324 of 901 windows
# [INFO] Processed 325 of 901 windows
# [INFO] Processed 326 of 901 windows
# [INFO] Processed 327 of 901 windows
# [INFO] Processed 328 of 901 windows
# [INFO] Processed 329 of 901 windows
# [INFO] Processed 330 of 901 windows
# [INFO] Processed 331 of 901 windows
# [INFO] Processed 332 of 901 windows
# [INFO] Processed 333 of 901 windows
# [INFO] Processed 334 of 901 windows
# [INFO] Processed 335 of 901 windows
# [INFO] Processed 336 of 901 windows
# [INFO] Processed 337 of 901 windows
# [INFO] Processed 338 of 901 windows
# [INFO] Processed 339 of 901 windows
# [INFO] Processed 340 of 901 windows
# [INFO] Processed 341 of 901 windows
# [INFO] Processed 342 of 901 windows
# [INFO] Processed 343 of 901 windows
# [INFO] Processed 344 of 901 windows
# [INFO] Processed 345 of 901 windows
# [INFO] Processed 346 of 901 windows
# [INFO] Processed 347 of 901 windows
# [INFO] Processed 348 of 901 windows
# [INFO] Processed 349 of 901 windows
# [INFO] Processed 350 of 901 windows
# [INFO] Processed 351 of 901 windows
# [INFO] Processed 352 of 901 windows
# [INFO] Processed 353 of 901 windows
# [INFO] Processed 354 of 901 windows
# [INFO] Processed 355 of 901 windows
# [INFO] Processed 356 of 901 windows
# [INFO] Processed 357 of 901 windows
# [INFO] Processed 358 of 901 windows
# [INFO] Processed 359 of 901 windows
# [INFO] Processed 360 of 901 windows
# [INFO] Processed 361 of 901 windows
# [INFO] Processed 362 of 901 windows
# [INFO] Processed 363 of 901 windows
# [INFO] Processed 364 of 901 windows
# [INFO] Processed 365 of 901 windows
# [INFO] Processed 366 of 901 windows
# [INFO] Processed 367 of 901 windows
# [INFO] Processed 368 of 901 windows
# [INFO] Processed 369 of 901 windows
# [INFO] Processed 370 of 901 windows
# [INFO] Processed 371 of 901 windows
# [INFO] Processed 372 of 901 windows
# [INFO] Processed 373 of 901 windows
# [INFO] Processed 374 of 901 windows
# [INFO] Processed 375 of 901 windows
# [INFO] Processed 376 of 901 windows
# [INFO] Processed 377 of 901 windows
# [INFO] Processed 378 of 901 windows
# [INFO] Processed 379 of 901 windows
# [INFO] Processed 380 of 901 windows
# [INFO] Processed 381 of 901 windows
# [INFO] Processed 382 of 901 windows
# [INFO] Processed 383 of 901 windows
# [INFO] Processed 384 of 901 windows
# [INFO] Processed 385 of 901 windows
# [INFO] Processed 386 of 901 windows
# [INFO] Processed 387 of 901 windows
# [INFO] Processed 388 of 901 windows
# [INFO] Processed 389 of 901 windows
# [INFO] Processed 390 of 901 windows
# [INFO] Processed 391 of 901 windows
# [INFO] Processed 392 of 901 windows
# [INFO] Processed 393 of 901 windows
# [INFO] Processed 394 of 901 windows
# [INFO] Processed 395 of 901 windows
# [INFO] Processed 396 of 901 windows
# [INFO] Processed 397 of 901 windows
# [INFO] Processed 398 of 901 windows
# [INFO] Processed 399 of 901 windows
# [INFO] Processed 400 of 901 windows
# [INFO] Processed 401 of 901 windows
# [INFO] Processed 402 of 901 windows
# [INFO] Processed 403 of 901 windows
# [INFO] Processed 404 of 901 windows
# [INFO] Processed 405 of 901 windows
# [INFO] Processed 406 of 901 windows
# [INFO] Processed 407 of 901 windows
# [INFO] Processed 408 of 901 windows
# [INFO] Processed 409 of 901 windows
# [INFO] Processed 410 of 901 windows
# [INFO] Processed 411 of 901 windows
# [INFO] Processed 412 of 901 windows
# [INFO] Processed 413 of 901 windows
# [INFO] Processed 414 of 901 windows
# [INFO] Processed 415 of 901 windows
# [INFO] Processed 416 of 901 windows
# [INFO] Processed 417 of 901 windows
# [INFO] Processed 418 of 901 windows
# [INFO] Processed 419 of 901 windows
# [INFO] Processed 420 of 901 windows
# [INFO] Processed 421 of 901 windows
# [INFO] Processed 422 of 901 windows
# [INFO] Processed 423 of 901 windows
# [INFO] Processed 424 of 901 windows
# [INFO] Processed 425 of 901 windows
# [INFO] Processed 426 of 901 windows
# [INFO] Processed 427 of 901 windows
# [INFO] Processed 428 of 901 windows
# [INFO] Processed 429 of 901 windows
# [INFO] Processed 430 of 901 windows
# [INFO] Processed 431 of 901 windows
# [INFO] Processed 432 of 901 windows
# [INFO] Processed 433 of 901 windows
# [INFO] Processed 434 of 901 windows
# [INFO] Processed 435 of 901 windows
# [INFO] Processed 436 of 901 windows
# [INFO] Processed 437 of 901 windows
# [INFO] Processed 438 of 901 windows
# [INFO] Processed 439 of 901 windows
# [INFO] Processed 440 of 901 windows
# [INFO] Processed 441 of 901 windows
# [INFO] Processed 442 of 901 windows
# [INFO] Processed 443 of 901 windows
# [INFO] Processed 444 of 901 windows
# [INFO] Processed 445 of 901 windows
# [INFO] Processed 446 of 901 windows
# [INFO] Processed 447 of 901 windows
# [INFO] Processed 448 of 901 windows
# [INFO] Processed 449 of 901 windows
# [INFO] Processed 450 of 901 windows
# [INFO] Processed 451 of 901 windows
# [INFO] Processed 452 of 901 windows
# [INFO] Processed 453 of 901 windows
# [INFO] Processed 454 of 901 windows
# [INFO] Processed 455 of 901 windows
# [INFO] Processed 456 of 901 windows
# [INFO] Processed 457 of 901 windows
# [INFO] Processed 458 of 901 windows
# [INFO] Processed 459 of 901 windows
# [INFO] Processed 460 of 901 windows
# [INFO] Processed 461 of 901 windows
# [INFO] Processed 462 of 901 windows
# [INFO] Processed 463 of 901 windows
# [INFO] Processed 464 of 901 windows
# [INFO] Processed 465 of 901 windows
# [INFO] Processed 466 of 901 windows
# [INFO] Processed 467 of 901 windows
# [INFO] Processed 468 of 901 windows
# [INFO] Processed 469 of 901 windows
# [INFO] Processed 470 of 901 windows
# [INFO] Processed 471 of 901 windows
# [INFO] Processed 472 of 901 windows
# [INFO] Processed 473 of 901 windows
# [INFO] Processed 474 of 901 windows
# [INFO] Processed 475 of 901 windows
# [INFO] Processed 476 of 901 windows
# [INFO] Processed 477 of 901 windows
# [INFO] Processed 478 of 901 windows
# [INFO] Processed 479 of 901 windows
# [INFO] Processed 480 of 901 windows
# [INFO] Processed 481 of 901 windows
# [INFO] Processed 482 of 901 windows
# [INFO] Processed 483 of 901 windows
# [INFO] Processed 484 of 901 windows
# [INFO] Processed 485 of 901 windows
# [INFO] Processed 486 of 901 windows
# [INFO] Processed 487 of 901 windows
# [INFO] Processed 488 of 901 windows
# [INFO] Processed 489 of 901 windows
# [INFO] Processed 490 of 901 windows
# [INFO] Processed 491 of 901 windows
# [INFO] Processed 492 of 901 windows
# [INFO] Processed 493 of 901 windows
# [INFO] Processed 494 of 901 windows
# [INFO] Processed 495 of 901 windows
# [INFO] Processed 496 of 901 windows
# [INFO] Processed 497 of 901 windows
# [INFO] Processed 498 of 901 windows
# [INFO] Processed 499 of 901 windows
# [INFO] Processed 500 of 901 windows
# [INFO] Processed 501 of 901 windows
# [INFO] Processed 502 of 901 windows
# [INFO] Processed 503 of 901 windows
# [INFO] Processed 504 of 901 windows
# [INFO] Processed 505 of 901 windows
# [INFO] Processed 506 of 901 windows
# [INFO] Processed 507 of 901 windows
# [INFO] Processed 508 of 901 windows
# [INFO] Processed 509 of 901 windows
# [INFO] Processed 510 of 901 windows
# [INFO] Processed 511 of 901 windows
# [INFO] Processed 512 of 901 windows
# [INFO] Processed 513 of 901 windows
# [INFO] Processed 514 of 901 windows
# [INFO] Processed 515 of 901 windows
# [INFO] Processed 516 of 901 windows
# [INFO] Processed 517 of 901 windows
# [INFO] Processed 518 of 901 windows
# [INFO] Processed 519 of 901 windows
# [INFO] Processed 520 of 901 windows
# [INFO] Processed 521 of 901 windows
# [INFO] Processed 522 of 901 windows
# [INFO] Processed 523 of 901 windows
# [INFO] Processed 524 of 901 windows
# [INFO] Processed 525 of 901 windows
# [INFO] Processed 526 of 901 windows
# [INFO] Processed 527 of 901 windows
# [INFO] Processed 528 of 901 windows
# [INFO] Processed 529 of 901 windows
# [INFO] Processed 530 of 901 windows
# [INFO] Processed 531 of 901 windows
# [INFO] Processed 532 of 901 windows
# [INFO] Processed 533 of 901 windows
# [INFO] Processed 534 of 901 windows
# [INFO] Processed 535 of 901 windows
# [INFO] Processed 536 of 901 windows
# [INFO] Processed 537 of 901 windows
# [INFO] Processed 538 of 901 windows
# [INFO] Processed 539 of 901 windows
# [INFO] Processed 540 of 901 windows
# [INFO] Processed 541 of 901 windows
# [INFO] Processed 542 of 901 windows
# [INFO] Processed 543 of 901 windows
# [INFO] Processed 544 of 901 windows
# [INFO] Processed 545 of 901 windows
# [INFO] Processed 546 of 901 windows
# [INFO] Processed 547 of 901 windows
# [INFO] Processed 548 of 901 windows
# [INFO] Processed 549 of 901 windows
# [INFO] Processed 550 of 901 windows
# [INFO] Processed 551 of 901 windows
# [INFO] Processed 552 of 901 windows
# [INFO] Processed 553 of 901 windows
# [INFO] Processed 554 of 901 windows
# [INFO] Processed 555 of 901 windows
# [INFO] Processed 556 of 901 windows
# [INFO] Processed 557 of 901 windows
# [INFO] Processed 558 of 901 windows
# [INFO] Processed 559 of 901 windows
# [INFO] Processed 560 of 901 windows
# [INFO] Processed 561 of 901 windows
# [INFO] Processed 562 of 901 windows
# [INFO] Processed 563 of 901 windows
# [INFO] Processed 564 of 901 windows
# [INFO] Processed 565 of 901 windows
# [INFO] Processed 566 of 901 windows
# [INFO] Processed 567 of 901 windows
# [INFO] Processed 568 of 901 windows
# [INFO] Processed 569 of 901 windows
# [INFO] Processed 570 of 901 windows
# [INFO] Processed 571 of 901 windows
# [INFO] Processed 572 of 901 windows
# [INFO] Processed 573 of 901 windows
# [INFO] Processed 574 of 901 windows
# [INFO] Processed 575 of 901 windows
# [INFO] Processed 576 of 901 windows
# [INFO] Processed 577 of 901 windows
# [INFO] Processed 578 of 901 windows
# [INFO] Processed 579 of 901 windows
# [INFO] Processed 580 of 901 windows
# [INFO] Processed 581 of 901 windows
# [INFO] Processed 582 of 901 windows
# [INFO] Processed 583 of 901 windows
# [INFO] Processed 584 of 901 windows
# [INFO] Processed 585 of 901 windows
# [INFO] Processed 586 of 901 windows
# [INFO] Processed 587 of 901 windows
# [INFO] Processed 588 of 901 windows
# [INFO] Processed 589 of 901 windows
# [INFO] Processed 590 of 901 windows
# [INFO] Processed 591 of 901 windows
# [INFO] Processed 592 of 901 windows
# [INFO] Processed 593 of 901 windows
# [INFO] Processed 594 of 901 windows
# [INFO] Processed 595 of 901 windows
# [INFO] Processed 596 of 901 windows
# [INFO] Processed 597 of 901 windows
# [INFO] Processed 598 of 901 windows
# [INFO] Processed 599 of 901 windows
# [INFO] Processed 600 of 901 windows
# [INFO] Processed 601 of 901 windows
# [INFO] Processed 602 of 901 windows
# [INFO] Processed 603 of 901 windows
# [INFO] Processed 604 of 901 windows
# [INFO] Processed 605 of 901 windows
# [INFO] Processed 606 of 901 windows
# [INFO] Processed 607 of 901 windows
# [INFO] Processed 608 of 901 windows
# [INFO] Processed 609 of 901 windows
# [INFO] Processed 610 of 901 windows
# [INFO] Processed 611 of 901 windows
# [INFO] Processed 612 of 901 windows
# [INFO] Processed 613 of 901 windows
# [INFO] Processed 614 of 901 windows
# [INFO] Processed 615 of 901 windows
# [INFO] Processed 616 of 901 windows
# [INFO] Processed 617 of 901 windows
# [INFO] Processed 618 of 901 windows
# [INFO] Processed 619 of 901 windows
# [INFO] Processed 620 of 901 windows
# [INFO] Processed 621 of 901 windows
# [INFO] Processed 622 of 901 windows
# [INFO] Processed 623 of 901 windows
# [INFO] Processed 624 of 901 windows
# [INFO] Processed 625 of 901 windows
# [INFO] Processed 626 of 901 windows
# [INFO] Processed 627 of 901 windows
# [INFO] Processed 628 of 901 windows
# [INFO] Processed 629 of 901 windows
# [INFO] Processed 630 of 901 windows
# [INFO] Processed 631 of 901 windows
# [INFO] Processed 632 of 901 windows
# [INFO] Processed 633 of 901 windows
# [INFO] Processed 634 of 901 windows
# [INFO] Processed 635 of 901 windows
# [INFO] Processed 636 of 901 windows
# [INFO] Processed 637 of 901 windows
# [INFO] Processed 638 of 901 windows
# [INFO] Processed 639 of 901 windows
# [INFO] Processed 640 of 901 windows
# [INFO] Processed 641 of 901 windows
# [INFO] Processed 642 of 901 windows
# [INFO] Processed 643 of 901 windows
# [INFO] Processed 644 of 901 windows
# [INFO] Processed 645 of 901 windows
# [INFO] Processed 646 of 901 windows
# [INFO] Processed 647 of 901 windows
# [INFO] Processed 648 of 901 windows
# [INFO] Processed 649 of 901 windows
# [INFO] Processed 650 of 901 windows
# [INFO] Processed 651 of 901 windows
# [INFO] Processed 652 of 901 windows
# [INFO] Processed 653 of 901 windows
# [INFO] Processed 654 of 901 windows
# [INFO] Processed 655 of 901 windows
# [INFO] Processed 656 of 901 windows
# [INFO] Processed 657 of 901 windows
# [INFO] Processed 658 of 901 windows
# [INFO] Processed 659 of 901 windows
# [INFO] Processed 660 of 901 windows
# [INFO] Processed 661 of 901 windows
# [INFO] Processed 662 of 901 windows
# [INFO] Processed 663 of 901 windows
# [INFO] Processed 664 of 901 windows
# [INFO] Processed 665 of 901 windows
# [INFO] Processed 666 of 901 windows
# [INFO] Processed 667 of 901 windows
# [INFO] Processed 668 of 901 windows
# [INFO] Processed 669 of 901 windows
# [INFO] Processed 670 of 901 windows
# [INFO] Processed 671 of 901 windows
# [INFO] Processed 672 of 901 windows
# [INFO] Processed 673 of 901 windows
# [INFO] Processed 674 of 901 windows
# [INFO] Processed 675 of 901 windows
# [INFO] Processed 676 of 901 windows
# [INFO] Processed 677 of 901 windows
# [INFO] Processed 678 of 901 windows
# [INFO] Processed 679 of 901 windows
# [INFO] Processed 680 of 901 windows
# [INFO] Processed 681 of 901 windows
# [INFO] Processed 682 of 901 windows
# [INFO] Processed 683 of 901 windows
# [INFO] Processed 684 of 901 windows
# [INFO] Processed 685 of 901 windows
# [INFO] Processed 686 of 901 windows
# [INFO] Processed 687 of 901 windows
# [INFO] Processed 688 of 901 windows
# [INFO] Processed 689 of 901 windows
# [INFO] Processed 690 of 901 windows
# [INFO] Processed 691 of 901 windows
# [INFO] Processed 692 of 901 windows
# [INFO] Processed 693 of 901 windows
# [INFO] Processed 694 of 901 windows
# [INFO] Processed 695 of 901 windows
# [INFO] Processed 696 of 901 windows
# [INFO] Processed 697 of 901 windows
# [INFO] Processed 698 of 901 windows
# [INFO] Processed 699 of 901 windows
# [INFO] Processed 700 of 901 windows
# [INFO] Processed 701 of 901 windows
# [INFO] Processed 702 of 901 windows
# [INFO] Processed 703 of 901 windows
# [INFO] Processed 704 of 901 windows
# [INFO] Processed 705 of 901 windows
# [INFO] Processed 706 of 901 windows
# [INFO] Processed 707 of 901 windows
# [INFO] Processed 708 of 901 windows
# [INFO] Processed 709 of 901 windows
# [INFO] Processed 710 of 901 windows
# [INFO] Processed 711 of 901 windows
# [INFO] Processed 712 of 901 windows
# [INFO] Processed 713 of 901 windows
# [INFO] Processed 714 of 901 windows
# [INFO] Processed 715 of 901 windows
# [INFO] Processed 716 of 901 windows
# [INFO] Processed 717 of 901 windows
# [INFO] Processed 718 of 901 windows
# [INFO] Processed 719 of 901 windows
# [INFO] Processed 720 of 901 windows
# [INFO] Processed 721 of 901 windows
# [INFO] Processed 722 of 901 windows
# [INFO] Processed 723 of 901 windows
# [INFO] Processed 724 of 901 windows
# [INFO] Processed 725 of 901 windows
# [INFO] Processed 726 of 901 windows
# [INFO] Processed 727 of 901 windows
# [INFO] Processed 728 of 901 windows
# [INFO] Processed 729 of 901 windows
# [INFO] Processed 730 of 901 windows
# [INFO] Processed 731 of 901 windows
# [INFO] Processed 732 of 901 windows
# [INFO] Processed 733 of 901 windows
# [INFO] Processed 734 of 901 windows
# [INFO] Processed 735 of 901 windows
# [INFO] Processed 736 of 901 windows
# [INFO] Processed 737 of 901 windows
# [INFO] Processed 738 of 901 windows
# [INFO] Processed 739 of 901 windows
# [INFO] Processed 740 of 901 windows
# [INFO] Processed 741 of 901 windows
# [INFO] Processed 742 of 901 windows
# [INFO] Processed 743 of 901 windows
# [INFO] Processed 744 of 901 windows
# [INFO] Processed 745 of 901 windows
# [INFO] Processed 746 of 901 windows
# [INFO] Processed 747 of 901 windows
# [INFO] Processed 748 of 901 windows
# [INFO] Processed 749 of 901 windows
# [INFO] Processed 750 of 901 windows
# [INFO] Processed 751 of 901 windows
# [INFO] Processed 752 of 901 windows
# [INFO] Processed 753 of 901 windows
# [INFO] Processed 754 of 901 windows
# [INFO] Processed 755 of 901 windows
# [INFO] Processed 756 of 901 windows
# [INFO] Processed 757 of 901 windows
# [INFO] Processed 758 of 901 windows
# [INFO] Processed 759 of 901 windows
# [INFO] Processed 760 of 901 windows
# [INFO] Processed 761 of 901 windows
# [INFO] Processed 762 of 901 windows
# [INFO] Processed 763 of 901 windows
# [INFO] Processed 764 of 901 windows
# [INFO] Processed 765 of 901 windows
# [INFO] Processed 766 of 901 windows
# [INFO] Processed 767 of 901 windows
# [INFO] Processed 768 of 901 windows
# [INFO] Processed 769 of 901 windows
# [INFO] Processed 770 of 901 windows
# [INFO] Processed 771 of 901 windows
# [INFO] Processed 772 of 901 windows
# [INFO] Processed 773 of 901 windows
# [INFO] Processed 774 of 901 windows
# [INFO] Processed 775 of 901 windows
# [INFO] Processed 776 of 901 windows
# [INFO] Processed 777 of 901 windows
# [INFO] Processed 778 of 901 windows
# [INFO] Processed 779 of 901 windows
# [INFO] Processed 780 of 901 windows
# [INFO] Processed 781 of 901 windows
# [INFO] Processed 782 of 901 windows
# [INFO] Processed 783 of 901 windows
# [INFO] Processed 784 of 901 windows
# [INFO] Processed 785 of 901 windows
# [INFO] Processed 786 of 901 windows
# [INFO] Processed 787 of 901 windows
# [INFO] Processed 788 of 901 windows
# [INFO] Processed 789 of 901 windows
# [INFO] Processed 790 of 901 windows
# [INFO] Processed 791 of 901 windows
# [INFO] Processed 792 of 901 windows
# [INFO] Processed 793 of 901 windows
# [INFO] Processed 794 of 901 windows
# [INFO] Processed 795 of 901 windows
# [INFO] Processed 796 of 901 windows
# [INFO] Processed 797 of 901 windows
# [INFO] Processed 798 of 901 windows
# [INFO] Processed 799 of 901 windows
# [INFO] Processed 800 of 901 windows
# [INFO] Processed 801 of 901 windows
# [INFO] Processed 802 of 901 windows
# [INFO] Processed 803 of 901 windows
# [INFO] Processed 804 of 901 windows
# [INFO] Processed 805 of 901 windows
# [INFO] Processed 806 of 901 windows
# [INFO] Processed 807 of 901 windows
# [INFO] Processed 808 of 901 windows
# [INFO] Processed 809 of 901 windows
# [INFO] Processed 810 of 901 windows
# [INFO] Processed 811 of 901 windows
# [INFO] Processed 812 of 901 windows
# [INFO] Processed 813 of 901 windows
# [INFO] Processed 814 of 901 windows
# [INFO] Processed 815 of 901 windows
# [INFO] Processed 816 of 901 windows
# [INFO] Processed 817 of 901 windows
# [INFO] Processed 818 of 901 windows
# [INFO] Processed 819 of 901 windows
# [INFO] Processed 820 of 901 windows
# [INFO] Processed 821 of 901 windows
# [INFO] Processed 822 of 901 windows
# [INFO] Processed 823 of 901 windows
# [INFO] Processed 824 of 901 windows
# [INFO] Processed 825 of 901 windows
# [INFO] Processed 826 of 901 windows
# [INFO] Processed 827 of 901 windows
# [INFO] Processed 828 of 901 windows
# [INFO] Processed 829 of 901 windows
# [INFO] Processed 830 of 901 windows
# [INFO] Processed 831 of 901 windows
# [INFO] Processed 832 of 901 windows
# [INFO] Processed 833 of 901 windows
# [INFO] Processed 834 of 901 windows
# [INFO] Processed 835 of 901 windows
# [INFO] Processed 836 of 901 windows
# [INFO] Processed 837 of 901 windows
# [INFO] Processed 838 of 901 windows
# [INFO] Processed 839 of 901 windows
# [INFO] Processed 840 of 901 windows
# [INFO] Processed 841 of 901 windows
# [INFO] Processed 842 of 901 windows
# [INFO] Processed 843 of 901 windows
# [INFO] Processed 844 of 901 windows
# [INFO] Processed 845 of 901 windows
# [INFO] Processed 846 of 901 windows
# [INFO] Processed 847 of 901 windows
# [INFO] Processed 848 of 901 windows
# [INFO] Processed 849 of 901 windows
# [INFO] Processed 850 of 901 windows
# [INFO] Processed 851 of 901 windows
# [INFO] Processed 852 of 901 windows
# [INFO] Processed 853 of 901 windows
# [INFO] Processed 854 of 901 windows
# [INFO] Processed 855 of 901 windows
# [INFO] Processed 856 of 901 windows
# [INFO] Processed 857 of 901 windows
# [INFO] Processed 858 of 901 windows
# [INFO] Processed 859 of 901 windows
# [INFO] Processed 860 of 901 windows
# [INFO] Processed 861 of 901 windows
# [INFO] Processed 862 of 901 windows
# [INFO] Processed 863 of 901 windows
# [INFO] Processed 864 of 901 windows
# [INFO] Processed 865 of 901 windows
# [INFO] Processed 866 of 901 windows
# [INFO] Processed 867 of 901 windows
# [INFO] Processed 868 of 901 windows
# [INFO] Processed 869 of 901 windows
# [INFO] Processed 870 of 901 windows
# [INFO] Processed 871 of 901 windows
# [INFO] Processed 872 of 901 windows
# [INFO] Processed 873 of 901 windows
# [INFO] Processed 874 of 901 windows
# [INFO] Processed 875 of 901 windows
# [INFO] Processed 876 of 901 windows
# [INFO] Processed 877 of 901 windows
# [INFO] Processed 878 of 901 windows
# [INFO] Processed 879 of 901 windows
# [INFO] Processed 880 of 901 windows
# [INFO] Processed 881 of 901 windows
# [INFO] Processed 882 of 901 windows
# [INFO] Processed 883 of 901 windows
# [INFO] Processed 884 of 901 windows
# [INFO] Processed 885 of 901 windows
# [INFO] Processed 886 of 901 windows
# [INFO] Processed 887 of 901 windows
# [INFO] Processed 888 of 901 windows
# [INFO] Processed 889 of 901 windows
# [INFO] Processed 890 of 901 windows
# [INFO] Processed 891 of 901 windows
# [INFO] Processed 892 of 901 windows
# [INFO] Processed 893 of 901 windows
# [INFO] Processed 894 of 901 windows
# [INFO] Processed 895 of 901 windows
# [INFO] Processed 896 of 901 windows
# [INFO] Processed 897 of 901 windows
# [INFO] Processed 898 of 901 windows
# [INFO] Processed 899 of 901 windows
# [INFO] Processed 900 of 901 windows
# [INFO] Processed 901 of 901 windows
# [INFO] Processed 902 of 901 windows
#
# [INFO] Processed all windows

# %%
def parse_arguments():

    '''
    parse command line arguments and print help message if the number of arguments is different from what is expected
    '''

    # declare all variables global

    global gt_file_path, metadata_path, output_prefix, chrom, chrom_len, w_size, w_step, taxon, group, color_taxon, var_threshold, mean_threshold


    # fetch arguments
    
    _, gt_file_path, metadata_path, output_prefix, chrom, chrom_len, w_size, w_step, taxon, group, color_taxon, var_threshold, mean_threshold = sys.argv


    # print help message if incorrect number of arguments was specified

    if len(sys.argv) != 13:
        print('\nUsage:', file=sys.stderr)
        print('\tpython windowed_pca.py <genotype matrix> <metadata> <chromosome name> <chromosome length> <window size> <window step size> <filter column name> <filter column value> \ \n                         <color column name> <variance threshold> <mean threshold> <output prefix>\n', file=sys.stderr)
        print('\t\t<genotype matrix>\tstr\tpath to the genotype matrix file produced as described in the README', file=sys.stderr)
        print('\t\t<metadata>\t\tstr\tpath to the metadata file produced as described in the README', file=sys.stderr)
        print('\t\t<output prefix>\t\tstr\tprefix that will be used for all output files, can also be a directory to be created', file=sys.stderr)
        print('\t\t<chromosome name>\tstr\tname of the chromosome, e.g. "chr1"', file=sys.stderr)
        print('\t\t<chromosome length>\tint\tlength of the chromosome in bp, e.g. "32123123"', file=sys.stderr)
        print('\t\t<window size>\t\tint\tsize of the sliding window in bp, e.g. "1000000"', file=sys.stderr)
        print('\t\t<window step>\t\tint\tstep size of the sliding window in bp, e.g. "10000"', file=sys.stderr)
        print('\t\t<filter column name>\tstr\tset a metadata column name to be used to select individuals to be included in the analysis e.g. "genus" (see filter column value)', file=sys.stderr)
        print('\t\t<filter column value>\t\tstr\tselect a value to be filtered for in the defined filter column. Setting <filter column name> to "genus" and <filter column value> to "Homo" would include all individuals of the genus Homo in the output, and ignore all others. A comma-separated list of include values can be provided, to include for example a specific subset of genera ("Homo,Pan") ', file=sys.stderr)
        print('\t\t<color column name>\tstr\tselect a metadata column that will serve to partition included individuals into color groups in the output plots. If selecting e.g. "genus", all individuals from the same genus will have the same color in the output plots. If specifying a comma-separated list of column names (e.g. "genus,species"), two versions of each output plot will be produced, that differ only in the color scheme', file=sys.stderr)
        print('\t\t<variance threshold>\tint\trelevant to correct random switching along PC axes, see code for details, if unsure, use "9"', file=sys.stderr)
        print('\t\t<mean threshold>\tint\trelevant to correct random switching along PC axes, see code for details, if unsure, use "3"\n', file=sys.stderr)
        sys.exit()

    # allow to slecify no input sample filter
    if taxon == 'None': taxon = None
    if group == 'None': group = None

    # convert str to int where necessary (if var_threshold == False, assumes list of specific guide samples as mean_threshold)

    if not var_threshold == 'False':
        chrom_len, w_size, w_step, var_threshold, mean_threshold = int(chrom_len), int(w_size), int(w_step), int(var_threshold), int(mean_threshold)

    else:
        chrom_len, w_size, w_step = int(chrom_len), int(w_size), int(w_step)
    
    output_prefix = output_prefix.lower()

############################
